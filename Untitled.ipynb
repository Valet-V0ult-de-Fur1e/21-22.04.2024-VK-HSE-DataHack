# %%
# !pip install torch
# !pip install numpy
# !pip install pandas
# !pip install openpyxl
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in ./.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: filelock in ./.local/lib/python3.9/site-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.9/site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in ./.local/lib/python3.9/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in ./.local/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in ./.local/lib/python3.9/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in ./.local/lib/python3.9/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.local/lib/python3.9/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.local/lib/python3.9/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.local/lib/python3.9/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.local/lib/python3.9/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.local/lib/python3.9/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.local/lib/python3.9/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.local/lib/python3.9/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in ./.local/lib/python3.9/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.local/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in ./.local/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in ./.local/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (23.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 50.3 MB/s eta 0:00:0000:010:01
# Downloading contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 43.5 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 63.9 MB/s eta 0:00:0000:01:00:01
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 103.8 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 59.1 MB/s eta 0:00:0000:01:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib

# %%
import numpy as np
import pandas as pd

# %%
# import torch

# torch.cuda.is_available()

# %%
# excel_file = "data.mail.xlsx"
# all_sheets = pd.read_excel(excel_file, sheet_name=None)
# sheets = all_sheets.keys()
# for sheet_name in sheets:
#     sheet = pd.read_excel(excel_file, sheet_name=sheet_name)
#     sheet.to_csv("%s.csv" % sheet_name, index=False)

# %%
pd.read_csv("dom.mail.csv")
# Out:
#                                                     URL  \
# 0     https://dom.mail.ru/articles/74503-nazvano-neo...
# 1     https://dom.mail.ru/articles/74440-nazvana-tse...
# 2     https://dom.mail.ru/articles/74442-rianna-vyst...
# 3     https://dom.mail.ru/articles/74511-pereplata-p...
# 4     https://dom.mail.ru/articles/74521-dolgosrochn...
# ...                                                 ...
# 6480  https://dom.mail.ru/articles/18974-porazitelny...
# 6481  https://dom.mail.ru/articles/18854-neobychnye-...
# 6482  https://dom.mail.ru/articles/18804-samye-neoby...
# 6483  https://dom.mail.ru/articles/17940-udivitelnye...
# 6484  https://dom.mail.ru/articles/17705-top-10-samy...
#
#                                                   Title  \
# 0     Названо неожиданное преимущество проживания в ...
# 1            Названа цена самой дешевой студии в Москве
# 2     Рианна выставила на продажу принадлежавший Мэт...
# 3     Переплата по ипотеке для россиян составит четы...
# 4     Долгосрочная или краткосрочная аренда: что выг...
# ...                                                 ...
# 6480           Поразительные здания в форме букв (фото)
# 6481          Необычные проекты загородных домов (фото)
# 6482               Самые необычные здания рынков (фото)
# 6483                  Удивительные здания: дома-«штаны»
# 6484      Топ-10 самых высоких зданий в регионах России
#
#                                             Description  \
# 0     BMJ: жизнь в озелененном районе снижает риск р...
# 1     Всего на первичном рынке жилой недвижимости в ...
# 2     Певица купила квартиру около года назад и хоче...
# 3     Россияне, взявшие ипотеку по текущим ставкам, ...
# 4     Один из наиболее популярных способов получения...
# ...                                                 ...
# 6480                  Пока это единичные объекты в мире
# 6481  Шары на деревьях, огромный кристалл и спящая л...
# 6482  Мировые торговые постройки с необычной архитек...
# 6483  Западные архитекторы насмешили китайцев небоск...
# 6484  Объекты выше 100 метров, построенные за предел...
#
#                                            Article Text   Keywords
# 0     Ученые из государственного университета в Чанш...      Город
# 1     Там также нашли самое дорогое и наиболее дешев...      Город
# 2     Певица приобрела жилище всего около года назад...      Город
# 3     Россияне, взявшие ипотеку по текущим ставкам, ...      Город
# 4     Долгосрочная аренда Долгосрочная аренда — это ...      Город
# ...                                                 ...        ...
# 6480  Современные архитекторы не перестают поражать ...  Интерьеры
# 6481  Большинство загородных домов в нашей стране - ...  Интерьеры
# 6482  У большинства людей рынок ассоциируется прежде...  Интерьеры
# 6483  За последние годы Китай стал безусловным миров...  Интерьеры
# 6484  Известно, что самые высокие небоскребы России ...  Интерьеры
#
# [6485 rows x 5 columns]
